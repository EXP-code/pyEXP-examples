# %% [markdown]
# # An EXP simulation using pyEXP from a notebook: a disk-halo simulation with velocity coefficients
#
# This notebook uses `k3d` for three-dimensional respresentation of contours.  If you do not have `k3d`,  you will need to `pip install k3d` if you would like to see the three-dimensional views.  The Docker container has `k3d` preinstalled.
#
# We begin by importing `pyEXP` and friends and setting the working directory.

# %%
import os
import yaml
import pyEXP
import numpy as np
import matplotlib.pyplot as plt
# plt.rcParams['figure.figsize'] = [12, 9]

os.chdir('DiskHalo')

# Print the current working directory for reference
print(os.getcwd())
# Out:
# /home/weinberg/Projects/pyEXP-examples/Tutorials/EXP/DiskHalo

# %% [markdown]
# ## Running EXP
#
# If you have a full EXP install or are using the Docker image, you can run EXP from inside Jupyter to generate new simulations.  We'll do
# and example here using the periodic cube.

# %% [markdown]
# ### Generating initial conditions
#
# The full install has a body generator for the galaxy initial conditions called `gendisk`.   This code uses an Eddington inversion to
# generate spherical halo initial condtions and Jeans equations to generate disk initial conditions.  It will generate the cylindrical
# basis at the same time.  This step takes some time, so please be prepared to wait for 10 or 15 minutes.  Try it as follows:

# %%
! mpirun gendisk --ASCALE=0.01 --HSCALE=0.002 --scale_length=0.01 --scale_height=0.002 --LMAX=2 --MMAX=2 --NMAXH=6 --NMAXD=8 --NODD=2 --RMIN=0.0001 --nhalo=60000 --ndisk=20000 --cachefile=eof.cache.test
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%% Node, process, and communicator assignment %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#   Node # |             Hostname |      PID |     Status
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#        0 |                raven |  1091288 |       ROOT
#        1 |                raven |  1091289 |    WORKER 0
#        2 |                raven |  1091290 |    WORKER 1
#        3 |                raven |  1091291 |    WORKER 2
#        4 |                raven |  1091292 |    WORKER 3
#        5 |                raven |  1091293 |    WORKER 4
#        6 |                raven |  1091294 |    WORKER 5
#        7 |                raven |  1091296 |    WORKER 6
#        8 |                raven |  1091300 |    WORKER 7
#        9 |                raven |  1091304 |    WORKER 8
#       10 |                raven |  1091306 |    WORKER 9
#       11 |                raven |  1091307 |    WORKER 10
#       12 |                raven |  1091308 |    WORKER 11
#       13 |                raven |  1091309 |    WORKER 12
# ---- DiskType is <exponential>
# ---- Number of threads=1
# ---- Maximum # threads=1
# ---- SLGridSph::ReadH5Cache: successfully read basis cache <.slgrid_sph_cache>
# ---- EmpCylSL::ReadH5Cache: read <eof.cache.test>
# ---- EmpCylSL::read_cache: table forwarded to all processes
# EmpCylSL requested cache read: GOOD, continuing
# Initializing for a SINGLE-MASS halo . . . done
# Generating halo coordinates . . .
#      *****  min(r)=0.000694815  max(r)=1.99988
#  (x, y, z)=(0.000310363, 0.000376549, 0.00193222)
# done
# Generating disk coordinates . . .
#      *****  min(r)=0.000122959  max(r)=0.131088
#      ***** (x, y, z)=(-7.01295e-05, 9.23864e-06, 1.19417e-06)
# done
# Beginning halo accumulation . . . done
# Beginning disk accumulation . . . done
# Making disk coefficients . . . done
# Reexpand . . . done
# Generating halo velocities . . .
# [table]  (u, v, w)=(0.00434421, -0.00150984, -0.00288594)
# Velocity calls: Eddington=60000 Jeans=0
# done
# Generating disk velocities . . .
#
# Table disk epi parameters:
#   RDMIN=0.0001
#    maxr=0.131153
#    maxz=0.032
#    Xmin=-9.21034
#    Xmax=-2.03139
#    dR=0.00898492
#    dZ=4.00501e-05
#
# Nzero=13/50
# Nzero=220/800
#
#  *** Processor phi angles ***
# #   0:          0         1
# #   1:          1         2
# #   2:          2         3
# #   3:          3         4
# #   4:          4         5
# #   5:          5         6
# #   6:          6         7
# #   7:          7         8
# #   8:          0         0
# #   9:          0         0
# #  10:          0         0
# #  11:          0         0
# #  12:          0         0
# #  13:          0         0
# NZEPI=17/800
# [table]      ***** (u, v, w)=(-2.81467e-05, 0.000229858, 0.000128237)
#      ***** maxVZ=0.36772 (0.000736468), maxVR=5.73656 (9.25592e-05), maxVP=1.43414 (9.25592e-05)
#      ***** # adrift overrides=703
# done
# Writing phase space file for halo . . . done
# Writing phase space file for disk . . . done
#
# ****************************
#   KE_halo  = 0.970915
#   KE_disk  = 0.0522698
#
#   PE_halo(halo)  = -1.71284
#   PE_halo(disk)  = -0.304769
#   PE_disk(disk)  = -0.0683718
#   PE_disk(halo)  = -0.0383236
#
# -2T/W_halo = 0.962441
# -2T/W_disk = 0.979796
#
#  Halo mass=1.325  Disk mass=0.05
#
#   KE       = 1.02319
#   PE       = -2.12431
#  -2T/W     = 0.963312
# ****************************

# %% [markdown]
# A few comments on `gendisk` parameters used above:
# - `ASCALE` is the scale length for the basis function construction
# - `HSCALE` is the scale height for the basis function construction
# - `scale_length` is the scale length for the particle distribution
# - `scale_height` is the scale height for the particle distribution
# - `LMAX` is the maximum spherical order for the halo
# - `MMAX` is the maximum azimuthal order for the disk
# - `NMAXH` is the maximum radial order for the halo
# - `NMAXD` is the maximum radial order for the disk
# - `NODD` is the number of vertically antisymmetric functions per azimuthal order
# - `RMIN` is the minimum halo radius for internal tabulation
# - `nhalo` is the number of desired halo particles
# - `ndisk` is the number of desired disk particles
# - `ignore` if true, disk basis cache file is recomputed and rewritted, even if it exists
# - `cachefile` is the name of the disk basis cache file
#
# It almost always makes sense to set the basis and distribution scale lengths and heights to the same values.  But you have the
# option to vary those.  You can view all of the possible parameters using `gendisk -h`, but these are the most often used ones and
# the rest of sensible defaults for many cases.

# %% [markdown]
# ### Running the simulation

# %% [markdown]
# We have provided a sample `exp` configuration file in this working directory.  The default name for a configuration file is
# `config.yml`.  This run will take under an hour; and as little as 10 minutes on a modern laptop.  So be prepared to take a short
# break.  For maximum speed change `X` in the `-np X` argument to `mpirun` to the number of cores available in your CPU.
#
# The first shell command below empties the data directory, and the next is the`exp` launch command. The `exp` code will run for
# 500 steps.  You can estimate the total run time by looking at the last line of every step diagnostic stanza that estimates the
# time needed for each part of the caluculation.  The 'Total' field is the total run time in seconds per step.  E.g. if your computer
# is requiring 3 seconds per step, the completion time will be 25 minutes.

# %%
# %%time
! rm data/*
! mpirun exp config_vel.yml
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# #   Node name           PID         Executable
# -   ---------           ---         ----------
# 0   raven               1091531     exp
# 1   raven               1091532     exp
# 2   raven               1091533     exp
# 3   raven               1091534     exp
# 4   raven               1091535     exp
# 5   raven               1091536     exp
# 6   raven               1091537     exp
# 7   raven               1091538     exp
# 8   raven               1091539     exp
# 9   raven               1091541     exp
# 10  raven               1091544     exp
# 11  raven               1091547     exp
# 12  raven               1091550     exp
# 13  raven               1091552     exp
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
#
#
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%% This is EXP 7.8.4 %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%% Repository URL | https://github.com/EXP-code/EXP                         %
# %%%%% Current branch | fieldFixes                                              %
# %%%%% Current commit | f5cb1bcc215df2fcfb537dbc3535dc66357a57af                %
# %%%%% Compile time   | 2025-05-09 23:31:22 EDT                                 %
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
#
# ---- Random seed for Node 0 is: 11
# ---- Output path <data/> is a directory . . . good
# ---- Test file opened and deleted in output directory, good!
# ---- ComponentContainer can not find <processor.rates> . . . will assume homogeneous cluster
# ---- ComponentContainer could not open <data/OUT.run1.chkpt>, assuming a new run
# ---- SLGridSph::ReadH5Cache: error reading <data/sphereSL.cache.test>
# ---- SLGridSph::ReadH5Cache: HDF5 error is <Unable to open file data/sphereSL.cache.test (File accessibility) Unable to open file>
# ---- SLGridSph::WriteH5Cache: wrote <data/sphereSL.cache.test>
# ---- Sphere parameters:
# ----    lmax=4
# ----    nmax=12
# ----    rmapping=0.13065
# ----    cmap=1
# ----    rmin=2e-05
# ----    rmax=1.95
# ----    logr=false
# ----    NO_L0=false
# ----    NO_L1=false
# ----    EVEN_L=false
# ----    EVEN_M=false
# ----    M0_ONLY=false
# ----    selfgrav=true
# ---- Sphere: biorthogonal check passed
# ---- Component <dark halo>: user specified initial center: x, y, z: 0, 0, 0
# ---- Component <dark halo>: multistep level reporting every 1 steps
# ---- Component <dark halo>: multistep noswitching is false, freezeL is false, and last step criteria is true
# ---- EmpCylSL::ReadH5Cache: read <eof.cache.veltest>
# ---- EmpCylSL::read_cache: table forwarded to all processes
# ---- Cylinder parameters:
# ----    nmaxfid=64
# ----    lmaxfid=72
# ----    mmax=4
# ----    mlim=-1
# ----    nmax=12
# ----    ncylodd=4
# ----    rcylmin=0.001
# ----    rcylmax=20
# ----    acyl=0.01
# ----    hcyl=0.002
# ----    precond=true
# ----    pcavar=false
# ----    pcaeof=false
# ----    nvtk=1
# ----    npca=50
# ----    npca0=0
# ----    pcadiag=false
# ----    cachename=eof.cache.veltest
# ----    selfgrav=true
# ----    logarithmic=false
# ----    vflag=0
# ---- Cylinder: biorthogonal check passed
# ---- Component <star disk>: user specified initial center: x, y, z: 0, 0, 0
# ---- Component <star disk>: multistep level reporting every 1 steps
# ---- Component <star disk>: multistep noswitching is false, freezeL is false, and last step criteria is true
#
# Using the following component interation list:
# -----------------------------------------------------------------------
# dark halo                     acts on                     star disk
# -----------------------------------------------------------------------
# star disk                     acts on                     dark halo
# -----------------------------------------------------------------------
#
#
# ExternalCollection:
# -----------------------------------------------------------------------
# scandir: No such file or directory
# scandir: No such file or directory
# scandir: No such file or directory
# scandir: No such file or directory
# scandir: No such file or directory
# scandir: No such file or directory
# scandir: No such file or directory
# scandir: No such file or directory
# scandir: No such file or directory
# scandir: No such file or directory
# scandir: No such file or directory
# scandir: No such file or directory
# scandir: No such file or directory
# scandir: No such file or directory
# Loaded user libraries <>
# -----------------------------------------------------------------------
# Available user routines are <>
# -----------------------------------------------------------------------
#
# ------------------------------------------------------------------------
# No external force entries
# ------------------------------------------------------------------------
# FieldBasis::orthoTest: worst=3.43822e-15
# FieldBasis::orthoTest: worst=4.07282e-15
# OutCHKPT::Run(): error unlinking old backup file <data/OUT.run1.chkpt.bak>, it may not exist
# OutCHKPT: renaming backup file <data/OUT.run1.chkpt.bak>, it may not exist
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.3%
# --- Adj/Tot = 1.1%
# --- Update  = 2.8101e-03 sec
# --- Collate = 1.6702e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=1.775875e-06     < 7.812500e-06     [1]
# --- Max DT=2.407347e-02     > 2.000000e-03     [41860]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41860/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.002] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000393582        [  0.06 %]
# Velocity            : 0.00195226         [  0.29 %]
# Force               : 0.355926           [ 52.68 %]
# Coefs               : 0.109171           [ 16.16 %]
# Output              : 0.00642878         [  0.95 %]
# Levels              : 0.000785988        [  0.12 %]
# Report              : 1.541e-06          [  0.00 %]
# Balance             : 9.78e-07           [  0.00 %]
# Adjust              : 0.200841           [ 29.72 %]
# Total               : 0.675687           [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 11.7%
# --- Adj/Tot = 1.1%
# --- Update  = 9.6972e-03 sec
# --- Collate = 9.4444e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.409215e-02     > 2.000000e-03     [41864]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41864/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.004] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000616437        [  0.06 %]
# Velocity            : 0.00386427         [  0.35 %]
# Force               : 0.531294           [ 48.34 %]
# Coefs               : 0.182181           [ 16.58 %]
# Output              : 0.0123998          [  1.13 %]
# Levels              : 0.000528209        [  0.05 %]
# Report              : 1.27e-06           [  0.00 %]
# Balance             : 7.09e-07           [  0.00 %]
# Adjust              : 0.367858           [ 33.47 %]
# Total               : 1.09907            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 11.7%
# --- Adj/Tot = 1.3%
# --- Update  = 9.8285e-03 sec
# --- Collate = 6.5227e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.412303e-02     > 2.000000e-03     [41867]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41867/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.006] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00175928         [  0.07 %]
# Velocity            : 0.00912981         [  0.36 %]
# Force               : 1.28592            [ 50.14 %]
# Coefs               : 0.443367           [ 17.29 %]
# Output              : 0.0241825          [  0.94 %]
# Levels              : 0.000609593        [  0.02 %]
# Report              : 1.162e-06          [  0.00 %]
# Balance             : 7.66e-07           [  0.00 %]
# Adjust              : 0.79886            [ 31.15 %]
# Total               : 2.56454            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.7%
# --- Adj/Tot = 1.2%
# --- Update  = 1.0253e-02 sec
# --- Collate = 7.2538e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.412246e-02     > 2.000000e-03     [41878]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41878/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.008] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00179146         [  0.07 %]
# Velocity            : 0.00898961         [  0.35 %]
# Force               : 1.2707             [ 50.12 %]
# Coefs               : 0.435731           [ 17.19 %]
# Output              : 0.0240642          [  0.95 %]
# Levels              : 0.000481553        [  0.02 %]
# Report              : 1.398e-06          [  0.00 %]
# Balance             : 9.59e-07           [  0.00 %]
# Adjust              : 0.792881           [ 31.27 %]
# Total               : 2.53533            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.6%
# --- Adj/Tot = 1.2%
# --- Update  = 9.7760e-03 sec
# --- Collate = 8.7839e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.774434e-06     < 7.812500e-06     [2]
# --- Max DT=2.410110e-02     > 2.000000e-03     [41858]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 2/20000
#          Component <dark halo> |  high: 41858/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.01] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00173745         [  0.07 %]
# Velocity            : 0.00927637         [  0.37 %]
# Force               : 1.27101            [ 50.35 %]
# Coefs               : 0.435365           [ 17.25 %]
# Output              : 0.0239111          [  0.95 %]
# Levels              : 0.000561629        [  0.02 %]
# Report              : 1.152e-06          [  0.00 %]
# Balance             : 8.3e-07            [  0.00 %]
# Adjust              : 0.781594           [ 30.96 %]
# Total               : 2.52416            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 10.8%
# --- Adj/Tot = 1.1%
# --- Update  = 9.5163e-03 sec
# --- Collate = 7.3984e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.407659e-02     > 2.000000e-03     [41818]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41818/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.012] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00170679         [  0.07 %]
# Velocity            : 0.00938398         [  0.37 %]
# Force               : 1.29745            [ 50.67 %]
# Coefs               : 0.440646           [ 17.21 %]
# Output              : 0.0238068          [  0.93 %]
# Levels              : 0.000535398        [  0.02 %]
# Report              : 1.175e-06          [  0.00 %]
# Balance             : 5.83e-07           [  0.00 %]
# Adjust              : 0.786351           [ 30.71 %]
# Total               : 2.56057            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 11.4%
# --- Adj/Tot = 1.3%
# --- Update  = 9.5338e-03 sec
# --- Collate = 6.5881e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.409330e-02     > 2.000000e-03     [41800]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41800/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.014] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00172733         [  0.07 %]
# Velocity            : 0.00913131         [  0.36 %]
# Force               : 1.29616            [ 50.61 %]
# Coefs               : 0.439368           [ 17.16 %]
# Output              : 0.0238769          [  0.93 %]
# Levels              : 0.000488281        [  0.02 %]
# Report              : 1.109e-06          [  0.00 %]
# Balance             : 7.03e-07           [  0.00 %]
# Adjust              : 0.789468           [ 30.83 %]
# Total               : 2.56091            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 11.7%
# --- Adj/Tot = 1.2%
# --- Update  = 1.0392e-02 sec
# --- Collate = 9.6469e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.411855e-02     > 2.000000e-03     [41814]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41814/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.016] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00141198         [  0.06 %]
# Velocity            : 0.00536987         [  0.22 %]
# Force               : 1.29008            [ 52.43 %]
# Coefs               : 0.439717           [ 17.87 %]
# Output              : 0.0128042          [  0.52 %]
# Levels              : 0.000414121        [  0.02 %]
# Report              : 6.32e-07           [  0.00 %]
# Balance             : 6.97e-07           [  0.00 %]
# Adjust              : 0.710258           [ 28.87 %]
# Total               : 2.46059            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 13.9%
# --- Adj/Tot = 1.3%
# --- Update  = 9.4402e-03 sec
# --- Collate = 8.8147e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.411211e-02     > 2.000000e-03     [41809]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41809/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.018] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00103961         [  0.04 %]
# Velocity            : 0.00525543         [  0.21 %]
# Force               : 1.31058            [ 52.55 %]
# Coefs               : 0.44977            [ 18.03 %]
# Output              : 0.0133969          [  0.54 %]
# Levels              : 0.00047855         [  0.02 %]
# Report              : 1.08e-06           [  0.00 %]
# Balance             : 7.79e-07           [  0.00 %]
# Adjust              : 0.713051           [ 28.59 %]
# Total               : 2.49414            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 13.3%
# --- Adj/Tot = 1.3%
# --- Update  = 9.3488e-03 sec
# --- Collate = 6.1603e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.408648e-02     > 2.000000e-03     [41798]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41798/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.02] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00101203         [  0.04 %]
# Velocity            : 0.00451784         [  0.18 %]
# Force               : 1.24694            [ 49.90 %]
# Coefs               : 0.429396           [ 17.18 %]
# Output              : 0.126182           [  5.05 %]
# Levels              : 0.000352689        [  0.01 %]
# Report              : 1.214e-06          [  0.00 %]
# Balance             : 7.22e-07           [  0.00 %]
# Adjust              : 0.690082           [ 27.61 %]
# Total               : 2.49902            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.8%
# --- Adj/Tot = 1.1%
# --- Update  = 9.2599e-03 sec
# --- Collate = 7.2316e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.409769e-02     > 2.000000e-03     [41810]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41810/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.022] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00169873         [  0.07 %]
# Velocity            : 0.00918087         [  0.37 %]
# Force               : 1.22013            [ 49.75 %]
# Coefs               : 0.425447           [ 17.35 %]
# Output              : 0.0238283          [  0.97 %]
# Levels              : 0.000536711        [  0.02 %]
# Report              : 1.438e-06          [  0.00 %]
# Balance             : 6.86e-07           [  0.00 %]
# Adjust              : 0.7708             [ 31.43 %]
# Total               : 2.45231            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 14.0%
# --- Adj/Tot = 1.4%
# --- Update  = 9.3146e-03 sec
# --- Collate = 6.4148e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.411534e-02     > 2.000000e-03     [41822]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41822/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.024] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00174237         [  0.07 %]
# Velocity            : 0.00934749         [  0.38 %]
# Force               : 1.20354            [ 49.25 %]
# Coefs               : 0.429373           [ 17.57 %]
# Output              : 0.0236572          [  0.97 %]
# Levels              : 0.000504256        [  0.02 %]
# Report              : 1.084e-06          [  0.00 %]
# Balance             : 7.81e-07           [  0.00 %]
# Adjust              : 0.774649           [ 31.70 %]
# Total               : 2.44352            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.4%
# --- Adj/Tot = 1.2%
# --- Update  = 9.3212e-03 sec
# --- Collate = 6.2815e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.412903e-02     > 2.000000e-03     [41808]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41808/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.026] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00176549         [  0.07 %]
# Velocity            : 0.00937778         [  0.37 %]
# Force               : 1.27309            [ 50.20 %]
# Coefs               : 0.433863           [ 17.11 %]
# Output              : 0.023705           [  0.93 %]
# Levels              : 0.000547479        [  0.02 %]
# Report              : 9.96e-07           [  0.00 %]
# Balance             : 8.54e-07           [  0.00 %]
# Adjust              : 0.793206           [ 31.27 %]
# Total               : 2.53628            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.6%
# --- Adj/Tot = 1.2%
# --- Update  = 9.2720e-03 sec
# --- Collate = 6.1221e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.412170e-02     > 2.000000e-03     [41816]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41816/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.028] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00177158         [  0.07 %]
# Velocity            : 0.00942658         [  0.38 %]
# Force               : 1.26446            [ 50.41 %]
# Coefs               : 0.431799           [ 17.22 %]
# Output              : 0.0240962          [  0.96 %]
# Levels              : 0.000542817        [  0.02 %]
# Report              : 1.103e-06          [  0.00 %]
# Balance             : 8.5e-07            [  0.00 %]
# Adjust              : 0.775334           [ 30.91 %]
# Total               : 2.50812            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 13.1%
# --- Adj/Tot = 1.3%
# --- Update  = 9.2213e-03 sec
# --- Collate = 6.9720e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.411303e-02     > 2.000000e-03     [41780]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41780/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.03] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00174685         [  0.07 %]
# Velocity            : 0.00876195         [  0.37 %]
# Force               : 1.17143            [ 48.99 %]
# Coefs               : 0.415775           [ 17.39 %]
# Output              : 0.0248213          [  1.04 %]
# Levels              : 0.000497537        [  0.02 %]
# Report              : 9.79e-07           [  0.00 %]
# Balance             : 8.34e-07           [  0.00 %]
# Adjust              : 0.767546           [ 32.10 %]
# Total               : 2.39132            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 14.3%
# --- Adj/Tot = 1.4%
# --- Update  = 9.3117e-03 sec
# --- Collate = 6.6384e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.408217e-02     > 2.000000e-03     [41793]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41793/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.032] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00174047         [  0.07 %]
# Velocity            : 0.00909998         [  0.37 %]
# Force               : 1.23319            [ 49.75 %]
# Coefs               : 0.426119           [ 17.19 %]
# Output              : 0.0241547          [  0.97 %]
# Levels              : 0.000529901        [  0.02 %]
# Report              : 1.149e-06          [  0.00 %]
# Balance             : 7.03e-07           [  0.00 %]
# Adjust              : 0.783141           [ 31.59 %]
# Total               : 2.47869            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 13.4%
# --- Adj/Tot = 1.2%
# --- Update  = 9.3780e-03 sec
# --- Collate = 6.5988e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.409777e-02     > 2.000000e-03     [41800]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41800/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.034] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00171211         [  0.07 %]
# Velocity            : 0.00905759         [  0.36 %]
# Force               : 1.25632            [ 50.13 %]
# Coefs               : 0.42726            [ 17.05 %]
# Output              : 0.0238311          [  0.95 %]
# Levels              : 0.000554532        [  0.02 %]
# Report              : 1.032e-06          [  0.00 %]
# Balance             : 7.58e-07           [  0.00 %]
# Adjust              : 0.786474           [ 31.38 %]
# Total               : 2.50593            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.6%
# --- Adj/Tot = 1.2%
# --- Update  = 9.4435e-03 sec
# --- Collate = 6.5573e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.410226e-02     > 2.000000e-03     [41806]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41806/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.036] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00171326         [  0.07 %]
# Velocity            : 0.00876813         [  0.37 %]
# Force               : 1.15225            [ 48.95 %]
# Coefs               : 0.413374           [ 17.56 %]
# Output              : 0.0230427          [  0.98 %]
# Levels              : 0.000533953        [  0.02 %]
# Report              : 1.086e-06          [  0.00 %]
# Balance             : 6.25e-07           [  0.00 %]
# Adjust              : 0.753408           [ 32.01 %]
# Total               : 2.35374            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.2%
# --- Adj/Tot = 1.1%
# --- Update  = 9.2272e-03 sec
# --- Collate = 6.9296e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.409326e-02     > 2.000000e-03     [41808]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41808/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.038] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00169388         [  0.07 %]
# Velocity            : 0.00888752         [  0.37 %]
# Force               : 1.16261            [ 48.95 %]
# Coefs               : 0.41329            [ 17.40 %]
# Output              : 0.0233491          [  0.98 %]
# Levels              : 0.000530352        [  0.02 %]
# Report              : 1.088e-06          [  0.00 %]
# Balance             : 7.37e-07           [  0.00 %]
# Adjust              : 0.763905           [ 32.17 %]
# Total               : 2.37494            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.8%
# --- Adj/Tot = 1.2%
# --- Update  = 9.3100e-03 sec
# --- Collate = 5.8899e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.408777e-02     > 2.000000e-03     [41807]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41807/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.04] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.0017256          [  0.07 %]
# Velocity            : 0.00890944         [  0.35 %]
# Force               : 1.187              [ 46.52 %]
# Coefs               : 0.419564           [ 16.44 %]
# Output              : 0.160843           [  6.30 %]
# Levels              : 0.000659112        [  0.03 %]
# Report              : 1.099e-06          [  0.00 %]
# Balance             : 1.12e-06           [  0.00 %]
# Adjust              : 0.772026           [ 30.26 %]
# Total               : 2.55141            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.1%
# --- Adj/Tot = 1.0%
# --- Update  = 9.2040e-03 sec
# --- Collate = 6.4623e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.409161e-02     > 2.000000e-03     [41835]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41835/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.042] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00163137         [  0.07 %]
# Velocity            : 0.00940713         [  0.40 %]
# Force               : 1.15435            [ 48.56 %]
# Coefs               : 0.42377            [ 17.83 %]
# Output              : 0.0237218          [  1.00 %]
# Levels              : 0.000483608        [  0.02 %]
# Report              : 1.409e-06          [  0.00 %]
# Balance             : 6.95e-07           [  0.00 %]
# Adjust              : 0.763252           [ 32.11 %]
# Total               : 2.37726            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.6%
# --- Adj/Tot = 1.1%
# --- Update  = 9.2699e-03 sec
# --- Collate = 6.5155e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.412079e-02     > 2.000000e-03     [41845]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41845/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.044] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.0016145          [  0.07 %]
# Velocity            : 0.00876959         [  0.37 %]
# Force               : 1.17816            [ 49.13 %]
# Coefs               : 0.417774           [ 17.42 %]
# Output              : 0.0233435          [  0.97 %]
# Levels              : 0.000532665        [  0.02 %]
# Report              : 1.24e-06           [  0.00 %]
# Balance             : 6.53e-07           [  0.00 %]
# Adjust              : 0.76701            [ 31.99 %]
# Total               : 2.39786            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 13.4%
# --- Adj/Tot = 1.2%
# --- Update  = 9.2098e-03 sec
# --- Collate = 6.6732e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.411265e-02     > 2.000000e-03     [41832]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41832/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.046] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00171712         [  0.07 %]
# Velocity            : 0.00915113         [  0.38 %]
# Force               : 1.17988            [ 49.26 %]
# Coefs               : 0.419575           [ 17.52 %]
# Output              : 0.0233642          [  0.98 %]
# Levels              : 0.000607128        [  0.03 %]
# Report              : 1.333e-06          [  0.00 %]
# Balance             : 8.89e-07           [  0.00 %]
# Adjust              : 0.760099           [ 31.74 %]
# Total               : 2.39506            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.1%
# --- Adj/Tot = 1.1%
# --- Update  = 9.9466e-03 sec
# --- Collate = 7.1089e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.849382e-06     < 7.812500e-06     [1]
# --- Max DT=2.410644e-02     > 2.000000e-03     [41835]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41835/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.048] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00174412         [  0.07 %]
# Velocity            : 0.00865482         [  0.36 %]
# Force               : 1.18276            [ 48.83 %]
# Coefs               : 0.421628           [ 17.41 %]
# Output              : 0.0235515          [  0.97 %]
# Levels              : 0.000465           [  0.02 %]
# Report              : 1.033e-06          [  0.00 %]
# Balance             : 8.69e-07           [  0.00 %]
# Adjust              : 0.782904           [ 32.32 %]
# Total               : 2.42238            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 13.0%
# --- Adj/Tot = 1.2%
# --- Update  = 9.1517e-03 sec
# --- Collate = 6.5666e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.410207e-02     > 2.000000e-03     [41845]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41845/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.05] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.0017707          [  0.07 %]
# Velocity            : 0.0094269          [  0.38 %]
# Force               : 1.26359            [ 50.29 %]
# Coefs               : 0.433562           [ 17.25 %]
# Output              : 0.0232842          [  0.93 %]
# Levels              : 0.000553564        [  0.02 %]
# Report              : 1.114e-06          [  0.00 %]
# Balance             : 5.69e-07           [  0.00 %]
# Adjust              : 0.78002            [ 31.04 %]
# Total               : 2.51285            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 15.1%
# --- Adj/Tot = 1.3%
# --- Update  = 9.4153e-03 sec
# --- Collate = 6.6695e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.412108e-02     > 2.000000e-03     [41849]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41849/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.052] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00169328         [  0.07 %]
# Velocity            : 0.00924633         [  0.37 %]
# Force               : 1.22612            [ 49.28 %]
# Coefs               : 0.428586           [ 17.23 %]
# Output              : 0.0242274          [  0.97 %]
# Levels              : 0.000529397        [  0.02 %]
# Report              : 1.178e-06          [  0.00 %]
# Balance             : 6.72e-07           [  0.00 %]
# Adjust              : 0.796941           [ 32.03 %]
# Total               : 2.48801            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.9%
# --- Adj/Tot = 1.2%
# --- Update  = 9.2605e-03 sec
# --- Collate = 6.8943e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.414109e-02     > 2.000000e-03     [41843]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41843/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.054] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00176171         [  0.07 %]
# Velocity            : 0.00909981         [  0.36 %]
# Force               : 1.25375            [ 49.90 %]
# Coefs               : 0.426019           [ 16.96 %]
# Output              : 0.0313794          [  1.25 %]
# Levels              : 0.000666015        [  0.03 %]
# Report              : 1.159e-06          [  0.00 %]
# Balance             : 4.42e-07           [  0.00 %]
# Adjust              : 0.78892            [ 31.40 %]
# Total               : 2.51228            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.5%
# --- Adj/Tot = 1.1%
# --- Update  = 9.2737e-03 sec
# --- Collate = 6.8665e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.415699e-02     > 2.000000e-03     [41844]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41844/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.056] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.0016652          [  0.07 %]
# Velocity            : 0.00876223         [  0.37 %]
# Force               : 1.14903            [ 49.03 %]
# Coefs               : 0.404913           [ 17.28 %]
# Output              : 0.0233191          [  1.00 %]
# Levels              : 0.000572435        [  0.02 %]
# Report              : 1.019e-06          [  0.00 %]
# Balance             : 8.44e-07           [  0.00 %]
# Adjust              : 0.754488           [ 32.20 %]
# Total               : 2.34339            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 12.2%
# --- Adj/Tot = 1.1%
# --- Update  = 9.1068e-03 sec
# --- Collate = 7.1233e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.414301e-02     > 2.000000e-03     [41831]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41831/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# ...
# Coefs               : 0.184214           [ 13.80 %]
# Output              : 0.0108419          [  0.81 %]
# Levels              : 0.000369188        [  0.03 %]
# Report              : 1.106e-06          [  0.00 %]
# Balance             : 5.08e-07           [  0.00 %]
# Adjust              : 0.637436           [ 47.76 %]
# Total               : 1.33474            [100.00 %]
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.2%
# --- Adj/Tot = 1.2%
# --- Update  = 8.1984e-03 sec
# --- Collate = 7.1417e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.082499e-06     < 7.812500e-06     [1]
# --- Max DT=2.373662e-02     > 2.000000e-03     [41650]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41650/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.984] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000950104        [  0.07 %]
# Velocity            : 0.00440844         [  0.32 %]
# Force               : 0.517512           [ 37.34 %]
# Coefs               : 0.189664           [ 13.68 %]
# Output              : 0.0124356          [  0.90 %]
# Levels              : 0.000467929        [  0.03 %]
# Report              : 6.81e-07           [  0.00 %]
# Balance             : 5.31e-07           [  0.00 %]
# Adjust              : 0.660105           [ 47.62 %]
# Total               : 1.38606            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.1%
# --- Adj/Tot = 1.1%
# --- Update  = 8.7176e-03 sec
# --- Collate = 7.4342e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.374043e-02     > 2.000000e-03     [41640]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41640/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.986] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000932895        [  0.07 %]
# Velocity            : 0.00440242         [  0.32 %]
# Force               : 0.508528           [ 37.20 %]
# Coefs               : 0.188423           [ 13.78 %]
# Output              : 0.0122477          [  0.90 %]
# Levels              : 0.000391772        [  0.03 %]
# Report              : 7.51e-07           [  0.00 %]
# Balance             : 6.46e-07           [  0.00 %]
# Adjust              : 0.651568           [ 47.66 %]
# Total               : 1.36699            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 4.9%
# --- Adj/Tot = 1.1%
# --- Update  = 8.3478e-03 sec
# --- Collate = 6.1091e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=1.542917e-06     < 7.812500e-06     [3]
# --- Max DT=2.374174e-02     > 2.000000e-03     [41638]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 3/20000
#          Component <dark halo> |  high: 41638/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.988] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000992448        [  0.07 %]
# Velocity            : 0.00436729         [  0.32 %]
# Force               : 0.515617           [ 37.31 %]
# Coefs               : 0.190096           [ 13.75 %]
# Output              : 0.012256           [  0.89 %]
# Levels              : 0.000396791        [  0.03 %]
# Report              : 8.71e-07           [  0.00 %]
# Balance             : 6.09e-07           [  0.00 %]
# Adjust              : 0.657848           [ 47.60 %]
# Total               : 1.38208            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 4.6%
# --- Adj/Tot = 1.3%
# --- Update  = 8.2308e-03 sec
# --- Collate = 6.2854e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.339022e-06     < 7.812500e-06     [1]
# --- Max DT=2.373915e-02     > 2.000000e-03     [41653]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41653/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.99] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000914773        [  0.07 %]
# Velocity            : 0.00429017         [  0.31 %]
# Force               : 0.514131           [ 37.39 %]
# Coefs               : 0.186568           [ 13.57 %]
# Output              : 0.0125767          [  0.91 %]
# Levels              : 0.00046943         [  0.03 %]
# Report              : 6.51e-07           [  0.00 %]
# Balance             : 5.45e-07           [  0.00 %]
# Adjust              : 0.655604           [ 47.68 %]
# Total               : 1.37507            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.6%
# --- Adj/Tot = 1.4%
# --- Update  = 8.7975e-03 sec
# --- Collate = 7.2717e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.373540e-02     > 2.000000e-03     [41666]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41666/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.992] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000974005        [  0.07 %]
# Velocity            : 0.00448397         [  0.32 %]
# Force               : 0.51646            [ 37.19 %]
# Coefs               : 0.187048           [ 13.47 %]
# Output              : 0.0129725          [  0.93 %]
# Levels              : 0.000431235        [  0.03 %]
# Report              : 1.184e-06          [  0.00 %]
# Balance             : 4.99e-07           [  0.00 %]
# Adjust              : 0.665786           [ 47.94 %]
# Total               : 1.38867            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.3%
# --- Adj/Tot = 1.4%
# --- Update  = 8.6461e-03 sec
# --- Collate = 6.3033e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.049561e-06     < 7.812500e-06     [3]
# --- Max DT=2.373262e-02     > 2.000000e-03     [41643]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 3/20000
#          Component <dark halo> |  high: 41643/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.994] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00106577         [  0.08 %]
# Velocity            : 0.00448357         [  0.33 %]
# Force               : 0.50111            [ 36.92 %]
# Coefs               : 0.184106           [ 13.56 %]
# Output              : 0.0122772          [  0.90 %]
# Levels              : 0.000355388        [  0.03 %]
# Report              : 5.9e-07            [  0.00 %]
# Balance             : 5.87e-07           [  0.00 %]
# Adjust              : 0.653522           [ 48.14 %]
# Total               : 1.35743            [100.00 %]
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.7%
# --- Adj/Tot = 1.2%
# --- Update  = 8.9475e-03 sec
# --- Collate = 7.7367e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=1.616332e-06     < 7.812500e-06     [1]
# --- Max DT=2.373078e-02     > 2.000000e-03     [41632]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41632/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.996] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000936767        [  0.07 %]
# Velocity            : 0.00409089         [  0.31 %]
# Force               : 0.498387           [ 37.27 %]
# Coefs               : 0.184455           [ 13.79 %]
# Output              : 0.0109281          [  0.82 %]
# Levels              : 0.000426832        [  0.03 %]
# Report              : 8.5e-07            [  0.00 %]
# Balance             : 4.69e-07           [  0.00 %]
# Adjust              : 0.637652           [ 47.68 %]
# Total               : 1.33735            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.4%
# --- Adj/Tot = 1.3%
# --- Update  = 8.8231e-03 sec
# --- Collate = 7.3933e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=1.181746e-06     < 7.812500e-06     [5]
# --- Max DT=2.373065e-02     > 2.000000e-03     [41625]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 5/20000
#          Component <dark halo> |  high: 41625/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=0.998] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00105299         [  0.08 %]
# Velocity            : 0.00475459         [  0.34 %]
# Force               : 0.511287           [ 37.08 %]
# Coefs               : 0.188349           [ 13.66 %]
# Output              : 0.0135216          [  0.98 %]
# Levels              : 0.000364751        [  0.03 %]
# Report              : 8.05e-07           [  0.00 %]
# Balance             : 5.99e-07           [  0.00 %]
# Adjust              : 0.658997           [ 47.79 %]
# Total               : 1.37885            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.4%
# --- Adj/Tot = 1.3%
# --- Update  = 8.9241e-03 sec
# --- Collate = 6.8247e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.174569e-06     < 7.812500e-06     [1]
# --- Max DT=2.373116e-02     > 2.000000e-03     [41613]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41613/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1] -------------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000918462        [  0.06 %]
# Velocity            : 0.00390071         [  0.26 %]
# Force               : 0.501286           [ 32.95 %]
# Coefs               : 0.183161           [ 12.04 %]
# Output              : 0.192253           [ 12.64 %]
# Levels              : 0.000378602        [  0.02 %]
# Report              : 7.76e-07           [  0.00 %]
# Balance             : 6.41e-07           [  0.00 %]
# Adjust              : 0.638984           [ 42.00 %]
# Total               : 1.52135            [100.00 %]
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# Process    0 on raven   pid=657274   ROOT NODE	 Exiting EXP
# Process    2 on raven   pid=657276   rank in WORKER: 2	 Exiting EXP
# Process    3 on raven   pid=657277   rank in WORKER: 3	 Exiting EXP
# ---- ---- ---- ---- ---- ---- Process    1 on raven   pid=657275   rank in WORKER: 1	 Exiting EXP
# Process    4 on raven   pid=657278   rank in WORKER: 4	 Exiting EXP
# Process    5 on raven   pid=657279   rank in WORKER: 5	 Exiting EXP
# ---- ---- ---- ---- Process    6 on raven   pid=657280   rank in WORKER: 6	 Exiting EXP
# ---- ---- ---- ---- ---- ---- ---- ---- Process    7 on raven   pid=657281   rank in WORKER: 7	 Exiting EXP
# Process    8 on raven   pid=657282   rank in WORKER: 8	 Exiting EXP
# Process    9 on raven   pid=657283   rank in WORKER: 9	 Exiting EXP
# Process   10 on raven   pid=657286   rank in WORKER: 10	 Exiting EXP
# Process   11 on raven   pid=657289   rank in WORKER: 11	 Exiting EXP
# ---- ---- ---- ---- ---- ---- Process   12 on raven   pid=657290   rank in WORKER: 12	 Exiting EXP
# Process   13 on raven   pid=657291   rank in WORKER: 13	 Exiting EXP
# ------------------- ---- -------------------------------------------------------
#
# CPU times: user 23 s, sys: 4.06 s, total: 27 s
# Wall time: 11min 25s

# %% [markdown]
# #### To get a longer time series, uncomment the next command to restart the run
#
# You can repeat this as many times as you like.  This will take the same amount of time as the _run_ from the previous code block.  That's why we've commented it out by default.

# %%
# ! mpirun exp config_vel.yml
# Out:
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.1%
# --- Adj/Tot = 1.1%
# --- Update  = 8.7564e-03 sec
# --- Collate = 6.4574e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.374086e-02     > 2.000000e-03     [41594]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41594/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.036] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00108655         [  0.08 %]
# Velocity            : 0.00442564         [  0.31 %]
# Force               : 0.547296           [ 38.05 %]
# Coefs               : 0.191045           [ 13.28 %]
# Output              : 0.0117379          [  0.82 %]
# Levels              : 0.000354657        [  0.02 %]
# Report              : 5.12e-07           [  0.00 %]
# Balance             : 6.34e-07           [  0.00 %]
# Adjust              : 0.681736           [ 47.40 %]
# Total               : 1.4382             [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.1%
# --- Adj/Tot = 1.3%
# --- Update  = 8.3856e-03 sec
# --- Collate = 6.4612e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=1.897428e-06     < 7.812500e-06     [1]
# --- Max DT=2.373657e-02     > 2.000000e-03     [41596]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41596/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.038] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000851989        [  0.06 %]
# Velocity            : 0.00379849         [  0.27 %]
# Force               : 0.535866           [ 37.71 %]
# Coefs               : 0.190968           [ 13.44 %]
# Output              : 0.00981973         [  0.69 %]
# Levels              : 0.000255689        [  0.02 %]
# Report              : 5.85e-07           [  0.00 %]
# Balance             : 5.11e-07           [  0.00 %]
# Adjust              : 0.678836           [ 47.78 %]
# Total               : 1.42089            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.2%
# --- Adj/Tot = 1.3%
# --- Update  = 9.2365e-03 sec
# --- Collate = 8.3742e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.373316e-02     > 2.000000e-03     [41598]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41598/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.04] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000869303        [  0.06 %]
# Velocity            : 0.00422596         [  0.28 %]
# Force               : 0.519765           [ 34.92 %]
# Coefs               : 0.183731           [ 12.34 %]
# Output              : 0.107104           [  7.20 %]
# Levels              : 0.000354362        [  0.02 %]
# Report              : 9.84e-07           [  0.00 %]
# Balance             : 6.9e-07            [  0.00 %]
# Adjust              : 0.671962           [ 45.14 %]
# Total               : 1.48849            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.6%
# --- Adj/Tot = 1.1%
# --- Update  = 9.0388e-03 sec
# --- Collate = 1.0133e-04 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.296557e-06     < 7.812500e-06     [1]
# --- Max DT=2.372926e-02     > 2.000000e-03     [41576]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41576/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.042] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000881189        [  0.06 %]
# Velocity            : 0.00455794         [  0.33 %]
# Force               : 0.523543           [ 37.54 %]
# Coefs               : 0.185096           [ 13.27 %]
# Output              : 0.0106332          [  0.76 %]
# Levels              : 0.000337715        [  0.02 %]
# Report              : 7.02e-07           [  0.00 %]
# Balance             : 3.99e-07           [  0.00 %]
# Adjust              : 0.669102           [ 47.98 %]
# Total               : 1.39461            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.4%
# --- Adj/Tot = 1.2%
# --- Update  = 9.0902e-03 sec
# --- Collate = 7.6890e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.117152e-06     < 7.812500e-06     [2]
# --- Max DT=2.372794e-02     > 2.000000e-03     [41584]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 2/20000
#          Component <dark halo> |  high: 41584/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.044] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000923727        [  0.06 %]
# Velocity            : 0.00437552         [  0.30 %]
# Force               : 0.547698           [ 37.60 %]
# Coefs               : 0.194271           [ 13.34 %]
# Output              : 0.0124897          [  0.86 %]
# Levels              : 0.000330115        [  0.02 %]
# Report              : 7.94e-07           [  0.00 %]
# Balance             : 5.72e-07           [  0.00 %]
# Adjust              : 0.696046           [ 47.78 %]
# Total               : 1.45666            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.0%
# --- Adj/Tot = 1.1%
# --- Update  = 9.0053e-03 sec
# --- Collate = 6.6252e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.462550e-06     < 7.812500e-06     [1]
# --- Max DT=2.372626e-02     > 2.000000e-03     [41594]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41594/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.046] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000881971        [  0.06 %]
# Velocity            : 0.00409534         [  0.29 %]
# Force               : 0.545805           [ 38.06 %]
# Coefs               : 0.192454           [ 13.42 %]
# Output              : 0.0101322          [  0.71 %]
# Levels              : 0.000406295        [  0.03 %]
# Report              : 8.61e-07           [  0.00 %]
# Balance             : 6.13e-07           [  0.00 %]
# Adjust              : 0.679682           [ 47.40 %]
# Total               : 1.43393            [100.00 %]
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.1%
# --- Adj/Tot = 1.2%
# --- Update  = 8.3186e-03 sec
# --- Collate = 6.3300e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.409790e-06     < 7.812500e-06     [2]
# --- Max DT=2.372996e-02     > 2.000000e-03     [41581]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 2/20000
#          Component <dark halo> |  high: 41581/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.048] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00100751         [  0.07 %]
# Velocity            : 0.00399131         [  0.28 %]
# Force               : 0.529189           [ 37.39 %]
# Coefs               : 0.187162           [ 13.22 %]
# Output              : 0.0107573          [  0.76 %]
# Levels              : 0.000331222        [  0.02 %]
# Report              : 1.138e-06          [  0.00 %]
# Balance             : 5.86e-07           [  0.00 %]
# Adjust              : 0.682547           [ 48.22 %]
# Total               : 1.41548            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.2%
# --- Adj/Tot = 1.2%
# --- Update  = 8.5475e-03 sec
# --- Collate = 7.1259e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.404229e-06     < 7.812500e-06     [1]
# --- Max DT=2.373293e-02     > 2.000000e-03     [41586]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41586/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.05] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000890481        [  0.06 %]
# Velocity            : 0.00390357         [  0.27 %]
# Force               : 0.533653           [ 37.45 %]
# Coefs               : 0.190205           [ 13.35 %]
# Output              : 0.0106179          [  0.75 %]
# Levels              : 0.000382388        [  0.03 %]
# Report              : 7.87e-07           [  0.00 %]
# Balance             : 7.45e-07           [  0.00 %]
# Adjust              : 0.684673           [ 48.05 %]
# Total               : 1.42484            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 6.8%
# --- Adj/Tot = 1.2%
# --- Update  = 8.3984e-03 sec
# --- Collate = 6.6829e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=8.594795e-07     < 7.812500e-06     [2]
# --- Max DT=2.373737e-02     > 2.000000e-03     [41586]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 2/20000
#          Component <dark halo> |  high: 41586/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.052] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000911815        [  0.06 %]
# Velocity            : 0.00421574         [  0.29 %]
# Force               : 0.549027           [ 38.05 %]
# Coefs               : 0.194432           [ 13.48 %]
# Output              : 0.0109741          [  0.76 %]
# Levels              : 0.000374472        [  0.03 %]
# Report              : 5.68e-07           [  0.00 %]
# Balance             : 5.33e-07           [  0.00 %]
# Adjust              : 0.682453           [ 47.30 %]
# Total               : 1.44289            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.7%
# --- Adj/Tot = 1.2%
# --- Update  = 8.9791e-03 sec
# --- Collate = 7.0730e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.072062e-06     < 7.812500e-06     [2]
# --- Max DT=2.373979e-02     > 2.000000e-03     [41608]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 2/20000
#          Component <dark halo> |  high: 41608/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.054] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000930999        [  0.07 %]
# Velocity            : 0.00423617         [  0.30 %]
# Force               : 0.532109           [ 37.64 %]
# Coefs               : 0.187971           [ 13.30 %]
# Output              : 0.0123267          [  0.87 %]
# Levels              : 0.000309233        [  0.02 %]
# Report              : 1.035e-06          [  0.00 %]
# Balance             : 6.73e-07           [  0.00 %]
# Adjust              : 0.675257           [ 47.77 %]
# Total               : 1.41366            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.2%
# --- Adj/Tot = 1.2%
# --- Update  = 9.1131e-03 sec
# --- Collate = 1.0245e-04 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.373200e-02     > 2.000000e-03     [41592]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41592/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.056] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00105601         [  0.07 %]
# Velocity            : 0.00476244         [  0.33 %]
# Force               : 0.532515           [ 37.23 %]
# Coefs               : 0.191032           [ 13.36 %]
# Output              : 0.0111561          [  0.78 %]
# Levels              : 0.000351847        [  0.02 %]
# Report              : 9.35e-07           [  0.00 %]
# Balance             : 7.14e-07           [  0.00 %]
# Adjust              : 0.68883            [ 48.16 %]
# Total               : 1.43022            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.5%
# --- Adj/Tot = 1.2%
# --- Update  = 9.0172e-03 sec
# --- Collate = 1.0866e-04 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.937408e-06     < 7.812500e-06     [1]
# --- Max DT=2.371951e-02     > 2.000000e-03     [41590]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41590/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.058] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000902258        [  0.06 %]
# Velocity            : 0.00411742         [  0.29 %]
# Force               : 0.545227           [ 37.90 %]
# Coefs               : 0.18985            [ 13.20 %]
# Output              : 0.0112366          [  0.78 %]
# Levels              : 0.000543923        [  0.04 %]
# Report              : 8.78e-07           [  0.00 %]
# Balance             : 4.41e-07           [  0.00 %]
# Adjust              : 0.686207           [ 47.70 %]
# Total               : 1.43857            [100.00 %]
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 6.4%
# --- Adj/Tot = 1.2%
# --- Update  = 8.6560e-03 sec
# --- Collate = 7.6113e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.760630e-06     < 7.812500e-06     [1]
# --- Max DT=2.371514e-02     > 2.000000e-03     [41585]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41585/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.06] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000947705        [  0.06 %]
# Velocity            : 0.00435237         [  0.28 %]
# Force               : 0.544311           [ 35.14 %]
# Coefs               : 0.194476           [ 12.56 %]
# Output              : 0.112498           [  7.26 %]
# Levels              : 0.000300815        [  0.02 %]
# Report              : 1.202e-06          [  0.00 %]
# Balance             : 8.43e-07           [  0.00 %]
# Adjust              : 0.691424           [ 44.64 %]
# Total               : 1.54882            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.6%
# --- Adj/Tot = 1.2%
# --- Update  = 8.6674e-03 sec
# --- Collate = 6.0141e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=1.066194e-06     < 7.812500e-06     [2]
# --- Max DT=2.371920e-02     > 2.000000e-03     [41576]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 2/20000
#          Component <dark halo> |  high: 41576/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.062] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00093605         [  0.07 %]
# Velocity            : 0.00401466         [  0.29 %]
# Force               : 0.51718            [ 37.30 %]
# Coefs               : 0.18938            [ 13.66 %]
# Output              : 0.010077           [  0.73 %]
# Levels              : 0.000360184        [  0.03 %]
# Report              : 8.42e-07           [  0.00 %]
# Balance             : 5.91e-07           [  0.00 %]
# Adjust              : 0.664199           [ 47.90 %]
# Total               : 1.3866             [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.2%
# --- Adj/Tot = 1.2%
# --- Update  = 8.4253e-03 sec
# --- Collate = 6.6712e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.372140e-02     > 2.000000e-03     [41560]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41560/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.064] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000961445        [  0.07 %]
# Velocity            : 0.00411418         [  0.29 %]
# Force               : 0.532569           [ 37.27 %]
# Coefs               : 0.192833           [ 13.50 %]
# Output              : 0.0103991          [  0.73 %]
# Levels              : 0.000347006        [  0.02 %]
# Report              : 5.85e-07           [  0.00 %]
# Balance             : 7.37e-07           [  0.00 %]
# Adjust              : 0.687182           [ 48.09 %]
# Total               : 1.42889            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.4%
# --- Adj/Tot = 1.2%
# --- Update  = 8.7936e-03 sec
# --- Collate = 7.6433e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.320670e-06     < 7.812500e-06     [1]
# --- Max DT=2.372267e-02     > 2.000000e-03     [41544]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41544/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.066] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000921841        [  0.06 %]
# Velocity            : 0.00381797         [  0.27 %]
# Force               : 0.539344           [ 37.59 %]
# Coefs               : 0.190873           [ 13.30 %]
# Output              : 0.0102599          [  0.72 %]
# Levels              : 0.000399337        [  0.03 %]
# Report              : 8.89e-07           [  0.00 %]
# Balance             : 7.06e-07           [  0.00 %]
# Adjust              : 0.688581           [ 48.00 %]
# Total               : 1.43467            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.5%
# --- Adj/Tot = 1.1%
# --- Update  = 9.0334e-03 sec
# --- Collate = 6.6942e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.887804e-06     < 7.812500e-06     [1]
# --- Max DT=2.372962e-02     > 2.000000e-03     [41555]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41555/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.068] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00102176         [  0.07 %]
# Velocity            : 0.0041643          [  0.29 %]
# Force               : 0.54171            [ 37.48 %]
# Coefs               : 0.192157           [ 13.29 %]
# Output              : 0.0118956          [  0.82 %]
# Levels              : 0.000382209        [  0.03 %]
# Report              : 1.23e-06           [  0.00 %]
# Balance             : 4.73e-07           [  0.00 %]
# Adjust              : 0.693592           [ 47.98 %]
# Total               : 1.44544            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.0%
# --- Adj/Tot = 1.1%
# --- Update  = 8.6498e-03 sec
# --- Collate = 9.0191e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=1.563251e-06     < 7.812500e-06     [2]
# --- Max DT=2.373381e-02     > 2.000000e-03     [41551]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 2/20000
#          Component <dark halo> |  high: 41551/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.07] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00087922         [  0.06 %]
# Velocity            : 0.00410834         [  0.29 %]
# Force               : 0.525552           [ 37.29 %]
# Coefs               : 0.189447           [ 13.44 %]
# Output              : 0.0102865          [  0.73 %]
# Levels              : 0.000288766        [  0.02 %]
# Report              : 8.41e-07           [  0.00 %]
# Balance             : 5.22e-07           [  0.00 %]
# Adjust              : 0.678505           [ 48.14 %]
# Total               : 1.40955            [100.00 %]
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 4.9%
# --- Adj/Tot = 1.0%
# --- Update  = 8.6706e-03 sec
# --- Collate = 6.4945e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.373306e-02     > 2.000000e-03     [41550]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41550/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.072] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000865765        [  0.06 %]
# Velocity            : 0.00407971         [  0.29 %]
# Force               : 0.519711           [ 37.48 %]
# Coefs               : 0.185027           [ 13.34 %]
# Output              : 0.0103721          [  0.75 %]
# Levels              : 0.000318614        [  0.02 %]
# Report              : 6.01e-07           [  0.00 %]
# Balance             : 5.88e-07           [  0.00 %]
# Adjust              : 0.665797           [ 48.02 %]
# Total               : 1.38664            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.2%
# --- Adj/Tot = 1.1%
# --- Update  = 9.0105e-03 sec
# --- Collate = 7.6299e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.373678e-02     > 2.000000e-03     [41569]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41569/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.074] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000855226        [  0.06 %]
# Velocity            : 0.00377933         [  0.28 %]
# Force               : 0.506136           [ 37.28 %]
# Coefs               : 0.182689           [ 13.46 %]
# Output              : 0.0100352          [  0.74 %]
# Levels              : 0.000419458        [  0.03 %]
# Report              : 1.06e-06           [  0.00 %]
# Balance             : 4.8e-07            [  0.00 %]
# Adjust              : 0.653305           [ 48.12 %]
# Total               : 1.35765            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.5%
# --- Adj/Tot = 1.1%
# --- Update  = 9.0890e-03 sec
# --- Collate = 7.1494e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.373965e-02     > 2.000000e-03     [41582]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41582/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.076] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000926877        [  0.07 %]
# Velocity            : 0.0038163          [  0.28 %]
# Force               : 0.51487            [ 37.39 %]
# Coefs               : 0.187238           [ 13.60 %]
# Output              : 0.00989553         [  0.72 %]
# Levels              : 0.000349034        [  0.03 %]
# Report              : 6.81e-07           [  0.00 %]
# Balance             : 5.87e-07           [  0.00 %]
# Adjust              : 0.659375           [ 47.89 %]
# Total               : 1.37692            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 6.2%
# --- Adj/Tot = 1.4%
# --- Update  = 8.9530e-03 sec
# --- Collate = 7.2705e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.666282e-06     < 7.812500e-06     [1]
# --- Max DT=2.373996e-02     > 2.000000e-03     [41583]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41583/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.078] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.0010033          [  0.07 %]
# Velocity            : 0.00410118         [  0.27 %]
# Force               : 0.568823           [ 37.70 %]
# Coefs               : 0.199547           [ 13.22 %]
# Output              : 0.0117526          [  0.78 %]
# Levels              : 0.000312532        [  0.02 %]
# Report              : 6.52e-07           [  0.00 %]
# Balance             : 5.1e-07            [  0.00 %]
# Adjust              : 0.722866           [ 47.91 %]
# Total               : 1.50895            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.1%
# --- Adj/Tot = 1.3%
# --- Update  = 8.9622e-03 sec
# --- Collate = 7.1742e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.714889e-06     < 7.812500e-06     [3]
# --- Max DT=2.374471e-02     > 2.000000e-03     [41572]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 3/20000
#          Component <dark halo> |  high: 41572/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.08] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000859349        [  0.05 %]
# Velocity            : 0.00376991         [  0.24 %]
# Force               : 0.553265           [ 35.04 %]
# Coefs               : 0.196214           [ 12.43 %]
# Output              : 0.12449            [  7.88 %]
# Levels              : 0.000339961        [  0.02 %]
# Report              : 6.98e-07           [  0.00 %]
# Balance             : 6.91e-07           [  0.00 %]
# Adjust              : 0.699696           [ 44.31 %]
# Total               : 1.57916            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.2%
# --- Adj/Tot = 1.2%
# --- Update  = 8.6480e-03 sec
# --- Collate = 6.6783e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.374400e-02     > 2.000000e-03     [41575]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41575/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.082] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00088976         [  0.06 %]
# Velocity            : 0.00414442         [  0.29 %]
# Force               : 0.545516           [ 37.84 %]
# Coefs               : 0.193275           [ 13.41 %]
# Output              : 0.0103097          [  0.72 %]
# Levels              : 0.000335724        [  0.02 %]
# Report              : 1.022e-06          [  0.00 %]
# Balance             : 4.73e-07           [  0.00 %]
# Adjust              : 0.686668           [ 47.63 %]
# Total               : 1.44159            [100.00 %]
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.4%
# --- Adj/Tot = 1.2%
# --- Update  = 8.9255e-03 sec
# --- Collate = 7.0683e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.184864e-06     < 7.812500e-06     [1]
# --- Max DT=2.373692e-02     > 2.000000e-03     [41578]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41578/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.084] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000923591        [  0.06 %]
# Velocity            : 0.00441903         [  0.31 %]
# Force               : 0.531868           [ 37.35 %]
# Coefs               : 0.192869           [ 13.54 %]
# Output              : 0.0114031          [  0.80 %]
# Levels              : 0.00035549         [  0.02 %]
# Report              : 7.67e-07           [  0.00 %]
# Balance             : 6.18e-07           [  0.00 %]
# Adjust              : 0.681674           [ 47.87 %]
# Total               : 1.42401            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 4.4%
# --- Adj/Tot = 1.1%
# --- Update  = 1.2748e-02 sec
# --- Collate = 8.3383e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.372747e-02     > 2.000000e-03     [41585]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41585/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.086] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00100534         [  0.07 %]
# Velocity            : 0.00472262         [  0.31 %]
# Force               : 0.564819           [ 37.10 %]
# Coefs               : 0.202094           [ 13.28 %]
# Output              : 0.014656           [  0.96 %]
# Levels              : 0.000497047        [  0.03 %]
# Report              : 9.51e-07           [  0.00 %]
# Balance             : 7.77e-07           [  0.00 %]
# Adjust              : 0.733993           [ 48.21 %]
# Total               : 1.52236            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.5%
# --- Adj/Tot = 1.1%
# --- Update  = 8.9628e-03 sec
# --- Collate = 8.4391e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.372140e-02     > 2.000000e-03     [41581]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41581/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.088] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.0014369          [  0.09 %]
# Velocity            : 0.00615723         [  0.39 %]
# Force               : 0.60088            [ 38.26 %]
# Coefs               : 0.201461           [ 12.83 %]
# Output              : 0.0181722          [  1.16 %]
# Levels              : 0.000483545        [  0.03 %]
# Report              : 9.93e-07           [  0.00 %]
# Balance             : 6.53e-07           [  0.00 %]
# Adjust              : 0.741052           [ 47.19 %]
# Total               : 1.57034            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.8%
# --- Adj/Tot = 1.3%
# --- Update  = 8.9736e-03 sec
# --- Collate = 9.9627e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.633932e-06     < 7.812500e-06     [1]
# --- Max DT=2.372253e-02     > 2.000000e-03     [41596]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41596/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.09] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00103493         [  0.07 %]
# Velocity            : 0.00448719         [  0.30 %]
# Force               : 0.564617           [ 37.34 %]
# Coefs               : 0.201866           [ 13.35 %]
# Output              : 0.0124876          [  0.83 %]
# Levels              : 0.000343621        [  0.02 %]
# Report              : 6.59e-07           [  0.00 %]
# Balance             : 6.57e-07           [  0.00 %]
# Adjust              : 0.726623           [ 48.06 %]
# Total               : 1.51201            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 7.3%
# --- Adj/Tot = 1.2%
# --- Update  = 9.0915e-03 sec
# --- Collate = 7.5607e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.145977e-06     < 7.812500e-06     [1]
# --- Max DT=2.372033e-02     > 2.000000e-03     [41597]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41597/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.092] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000782628        [  0.06 %]
# Velocity            : 0.00368441         [  0.26 %]
# Force               : 0.531538           [ 38.02 %]
# Coefs               : 0.1892             [ 13.53 %]
# Output              : 0.00924648         [  0.66 %]
# Levels              : 0.000386959        [  0.03 %]
# Report              : 1.146e-06          [  0.00 %]
# Balance             : 5.85e-07           [  0.00 %]
# Adjust              : 0.662644           [ 47.40 %]
# Total               : 1.39793            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.5%
# --- Adj/Tot = 1.2%
# --- Update  = 8.9654e-03 sec
# --- Collate = 7.4129e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Max DT=2.371758e-02     > 2.000000e-03     [41606]
# ----------------------------------------------------------------------
#          Component <dark halo> |  high: 41606/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.094] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000820209        [  0.06 %]
# Velocity            : 0.00376536         [  0.28 %]
# Force               : 0.511939           [ 37.58 %]
# Coefs               : 0.1846             [ 13.55 %]
# Output              : 0.00948048         [  0.70 %]
# Levels              : 0.000344037        [  0.03 %]
# Report              : 6.49e-07           [  0.00 %]
# Balance             : 7.21e-07           [  0.00 %]
# Adjust              : 0.650863           [ 47.78 %]
# Total               : 1.36225            [100.00 %]
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 4.4%
# --- Adj/Tot = 1.1%
# --- Update  = 9.7640e-03 sec
# --- Collate = 7.1924e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.876856e-06     < 7.812500e-06     [1]
# --- Max DT=2.371332e-02     > 2.000000e-03     [41624]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 41624/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.096] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.000959681        [  0.06 %]
# Velocity            : 0.00426737         [  0.29 %]
# ...
# Balance             : 6e-07              [  0.00 %]
# Adjust              : 0.681688           [ 44.15 %]
# Total               : 1.54392            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.7%
# --- Adj/Tot = 1.2%
# --- Update  = 7.7791e-03 sec
# --- Collate = 5.9179e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.576090e-06     < 7.812500e-06     [1]
# --- Max DT=2.314342e-02     > 2.000000e-03     [40980]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 40980/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.984] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00196515         [  0.13 %]
# Velocity            : 0.0103408          [  0.67 %]
# Force               : 0.616443           [ 39.92 %]
# Coefs               : 0.214139           [ 13.87 %]
# Output              : 0.0213225          [  1.38 %]
# Levels              : 0.000515976        [  0.03 %]
# Report              : 1.026e-06          [  0.00 %]
# Balance             : 6.17e-07           [  0.00 %]
# Adjust              : 0.678672           [ 43.95 %]
# Total               : 1.54402            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.2%
# --- Adj/Tot = 1.4%
# --- Update  = 8.2811e-03 sec
# --- Collate = 6.6174e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=1.617597e-06     < 7.812500e-06     [3]
# --- Max DT=2.314027e-02     > 2.000000e-03     [40996]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 3/20000
#          Component <dark halo> |  high: 40996/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.986] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00193554         [  0.12 %]
# Velocity            : 0.0100514          [  0.65 %]
# Force               : 0.61944            [ 39.79 %]
# Coefs               : 0.213514           [ 13.72 %]
# Output              : 0.0211423          [  1.36 %]
# Levels              : 0.000535964        [  0.03 %]
# Report              : 8.91e-07           [  0.00 %]
# Balance             : 5.63e-07           [  0.00 %]
# Adjust              : 0.689477           [ 44.29 %]
# Total               : 1.55673            [100.00 %]
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 6.4%
# --- Adj/Tot = 1.2%
# --- Update  = 8.3551e-03 sec
# --- Collate = 7.4067e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=1.345730e-06     < 7.812500e-06     [3]
# --- Max DT=2.314420e-02     > 2.000000e-03     [40994]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 3/20000
#          Component <dark halo> |  high: 40994/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.988] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00180615         [  0.12 %]
# Velocity            : 0.0096827          [  0.63 %]
# Force               : 0.610863           [ 39.85 %]
# Coefs               : 0.211447           [ 13.79 %]
# Output              : 0.0210955          [  1.38 %]
# Levels              : 0.000482368        [  0.03 %]
# Report              : 1.015e-06          [  0.00 %]
# Balance             : 6.63e-07           [  0.00 %]
# Adjust              : 0.677086           [ 44.17 %]
# Total               : 1.53306            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 6.5%
# --- Adj/Tot = 1.4%
# --- Update  = 8.4407e-03 sec
# --- Collate = 6.8537e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.036226e-06     < 7.812500e-06     [3]
# --- Max DT=2.314903e-02     > 2.000000e-03     [40986]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 3/20000
#          Component <dark halo> |  high: 40986/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.99] ----------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00202875         [  0.13 %]
# Velocity            : 0.0103923          [  0.66 %]
# Force               : 0.621              [ 39.73 %]
# Coefs               : 0.215225           [ 13.77 %]
# Output              : 0.0218552          [  1.40 %]
# Levels              : 0.000572095        [  0.04 %]
# Report              : 1.193e-06          [  0.00 %]
# Balance             : 7.07e-07           [  0.00 %]
# Adjust              : 0.691342           [ 44.23 %]
# Total               : 1.56301            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.3%
# --- Adj/Tot = 1.2%
# --- Update  = 7.9525e-03 sec
# --- Collate = 5.7432e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.598942e-06     < 7.812500e-06     [1]
# --- Max DT=2.315372e-02     > 2.000000e-03     [40993]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 40993/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.992] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00188642         [  0.12 %]
# Velocity            : 0.00967739         [  0.64 %]
# Force               : 0.605379           [ 39.80 %]
# Coefs               : 0.208843           [ 13.73 %]
# Output              : 0.0210122          [  1.38 %]
# Levels              : 0.000500387        [  0.03 %]
# Report              : 9.13e-07           [  0.00 %]
# Balance             : 6.28e-07           [  0.00 %]
# Adjust              : 0.673059           [ 44.25 %]
# Total               : 1.521              [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 6.1%
# --- Adj/Tot = 1.4%
# --- Update  = 9.8184e-03 sec
# --- Collate = 5.5494e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=1.714695e-06     < 7.812500e-06     [3]
# --- Max DT=2.315611e-02     > 2.000000e-03     [40993]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 3/20000
#          Component <dark halo> |  high: 40993/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.994] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00191103         [  0.12 %]
# Velocity            : 0.0102093          [  0.62 %]
# Force               : 0.642011           [ 39.14 %]
# Coefs               : 0.221242           [ 13.49 %]
# Output              : 0.0220301          [  1.34 %]
# Levels              : 0.000509764        [  0.03 %]
# Report              : 1.122e-06          [  0.00 %]
# Balance             : 5.91e-07           [  0.00 %]
# Adjust              : 0.741746           [ 45.22 %]
# Total               : 1.64028            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 5.3%
# --- Adj/Tot = 1.3%
# --- Update  = 9.0462e-03 sec
# --- Collate = 7.3095e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=3.017542e-06     < 7.812500e-06     [4]
# --- Max DT=2.315388e-02     > 2.000000e-03     [41009]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 4/20000
#          Component <dark halo> |  high: 41009/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.996] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.0021031          [  0.12 %]
# Velocity            : 0.0111663          [  0.62 %]
# Force               : 0.734144           [ 40.55 %]
# Coefs               : 0.255686           [ 14.12 %]
# Output              : 0.0223678          [  1.24 %]
# Levels              : 0.000575223        [  0.03 %]
# Report              : 9.81e-07           [  0.00 %]
# Balance             : 5.84e-07           [  0.00 %]
# Adjust              : 0.783902           [ 43.29 %]
# Total               : 1.81063            [100.00 %]
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 6.2%
# --- Adj/Tot = 1.4%
# --- Update  = 8.6972e-03 sec
# --- Collate = 7.5622e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.224837e-06     < 7.812500e-06     [3]
# --- Max DT=2.314294e-02     > 2.000000e-03     [40990]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 3/20000
#          Component <dark halo> |  high: 40990/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=1.998] ---------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00185935         [  0.11 %]
# Velocity            : 0.0111962          [  0.64 %]
# Force               : 0.696349           [ 39.93 %]
# Coefs               : 0.233014           [ 13.36 %]
# Output              : 0.0233945          [  1.34 %]
# Levels              : 0.000520284        [  0.03 %]
# Report              : 7.38e-07           [  0.00 %]
# Balance             : 5.77e-07           [  0.00 %]
# Adjust              : 0.776682           [ 44.54 %]
# Total               : 1.74373            [100.00 %]
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# --- Coefficient adjust stats
# --- Coef/DT = 6.6%
# --- Adj/Tot = 1.4%
# --- Update  = 8.4440e-03 sec
# --- Collate = 5.5060e-05 sec
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Multistepping overrun
# --- Min DT=2.388455e-06     < 7.812500e-06     [1]
# --- Max DT=2.313476e-02     > 2.000000e-03     [40998]
# ----------------------------------------------------------------------
#          Component <dark halo> |   low: 0/60000
#          Component <star disk> |   low: 1/20000
#          Component <dark halo> |  high: 40998/60000
#          Component <star disk> |  high: 0/20000
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
# --- Timer info [T=2] -------------------------------------------------
# ----------------------------------------------------------------------
# Drift               : 0.00183718         [  0.10 %]
# Velocity            : 0.00991056         [  0.52 %]
# Force               : 0.6646             [ 35.10 %]
# Coefs               : 0.223147           [ 11.79 %]
# Output              : 0.254339           [ 13.43 %]
# Levels              : 0.000458585        [  0.02 %]
# Report              : 2.1e-06            [  0.00 %]
# Balance             : 1.068e-06          [  0.00 %]
# Adjust              : 0.738509           [ 39.00 %]
# Total               : 1.89345            [100.00 %]
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# Process    0 on raven   pid=660066   ROOT NODE	 Exiting EXP
# ---- ---- Process    1 on raven   pid=660067   rank in WORKER: 1	 Exiting EXP
# Process ---- ----    2 on raven   pid=660068   rank in WORKER: 2	 Exiting EXP
# Process ---- ----    3 on raven   pid=660069   rank in WORKER: 3	 Exiting EXP
# ---- ---- Process    4 on raven   pid=660070   rank in WORKER: 4	 Exiting EXP
# ---- ---- ---- ---- Process    5 on raven   pid=660071   rank in WORKER: 5	 Exiting EXP
# Process    6 on raven   pid=660072   rank in WORKER: 6	 Exiting EXP
# ---- ---- ---- ---- Process    7 on raven   pid=660073   rank in WORKER: 7	 Exiting EXP
# Process    8 on raven   pid=660074   rank in WORKER: 8	 Exiting EXP
# ---- ---- Process    9 on raven   pid=660075   rank in WORKER: 9	 Exiting EXP
# Process ---- ----   10 on raven   pid=660078   rank in WORKER: 10	 Exiting EXP
# Process   11 on raven---- ----    pid=660081   rank in WORKER: 11	 Exiting EXP
# Process ---- ----   12 on raven   pid=660083   rank in WORKER: 12	 Exiting EXP
# ---- ---- Process   13 on raven   pid=660086   rank in WORKER: 13	 Exiting EXP
# ----------------------------------------------------------------------

# %% [markdown]
# ## Read the log file
#
# and plot the virial equilibrium as a function of time.  The log file records the center of mass, center of velocity, angular momentum,
# and energies for the total and for each component separately.  Here, we will plot the virial statistic as a diagnostic for equilibrium.

# %%
# First read in the config to get the runtag
with open('config_vel.yml', 'r') as f:
    yaml_db = yaml.load(f, Loader=yaml.FullLoader)

outdir = '.'
if 'outdir' in yaml_db['Global'].keys(): outdir = yaml_db['Global']['outdir']
runtag = yaml_db['Global']['runtag']
print('Outdir is {}'.format(outdir))
print('Runtag is {}'.format(runtag))
# Out:
# Outdir is data
# Runtag is run1

# %%
# !pwd
os.system('ls {}/OUTLOG.{}'.format(outdir, runtag))
# Out:
# /home/weinberg/Projects/pyEXP-examples/Tutorials/EXP/DiskHalo
# data/OUTLOG.run1
# 0

# %%
# This parses the  OUTLOG files generated by exp.  You can see available columns by printing the keys
# in the dictionary 'data'.  For this plot, we will only look at twice the ratio of kinetic energy to potential energy
# (estimated by the virial of Clausius).

def parseLog(outdir, runtag):
    path = outdir + '/OUTLOG.' + runtag
    file = open(path)
    # Get the column names
    labs = file.readlines()[2:3][0].split('|')
    # Get the data
    vals = np.loadtxt(outdir + '/OUTLOG.' + runtag, delimiter='|', skiprows=6)
    # Make a dictionary of columns
    data = {}
    for i in range(len(labs)):
        data[labs[i].strip()] = vals[:,i]
    return data

# Get the dictionary
data = parseLog(outdir, runtag)

# Make the plot
plt.plot(data['Time'], data['2T/VC'], label='Total')
plt.plot(data['Time'], data['star disk 2T/VC'], label = 'star disk')
plt.plot(data['Time'], data['dark halo 2T/VC'], label = 'dark halo')
plt.legend()
plt.tight_layout()
plt.xlabel('Time')
plt.ylabel('2T/VC')
plt.show()

# %% [markdown]
# ## Reading the disk coefficients
# This is a test of the coefficients created by the `EXP-examples/DiskHalo` run.

# %%
# Reread the coefs from the file.  These are new HDF5 coefficients sets.
#
coefs = pyEXP.coefs.Coefs.factory(outdir + '/outcoef.star disk.' + runtag)

print("Got coefs for name=", coefs.getName())
# Out:
# Got coefs for name= star disk

# %% [markdown]
# ### Now get the time vector and data tensor. Plot some coefficient series as a function of time.

# %%
times = coefs.Times()
data  = coefs.getAllCoefs()

print("The data sizes and coefficient orders are:")
print("M orders, N orders, Times:", data.shape)
# Out:
# The data sizes and coefficient orders are:
# M orders, N orders, Times: (5, 12, 1001)

# %% [markdown]
# ### Finally, plot some coefficient values...

# %%
for m in range(1, data.shape[0]):
    for n in range(4):
        plt.plot(times, np.abs(data[m, n, :]), label='{} {}'.format(m, n))

plt.xlabel('time')
plt.ylabel(r'$C_{mn}$')
plt.legend()
plt.show()

# %% [markdown]
# ## Try loading EXP config with pyYAML

# %%
with open('config_vel.yml', 'r') as f:
    yaml_db = yaml.load(f, Loader=yaml.FullLoader)

# The 0 index force is the halo and the 1 index force is the disk, e.g.:
for i in range(2):
    print('Index {} is {}'.format(i, yaml_db['Components'][i]['name']))

config = yaml.dump(yaml_db['Components'][1]['force'])
        
print('\nIndex 1 config is:', config)
# Out:
# Index 0 is dark halo
# Index 1 is star disk
#
# Index 1 config is: id: cylinder
# parameters:
#   acyl: 0.01
#   cachename: eof.cache.veltest
#   hcyl: 0.002
#   lmaxfid: 72
#   mmax: 4
#   ncylnx: 256
#   ncylny: 128
#   ncylodd: 4
#   nmax: 12
#   nmaxfid: 64

# %% [markdown]
# ## Construct the cylindrical basis
#
# This will use the previouisly computed basis cache

# %%
basis = pyEXP.basis.Basis.factory(config)
# Out:
# ---- EmpCylSL::ReadH5Cache: read <eof.cache.veltest>
# ---- EmpCylSL::read_cache: table forwarded to all processes
# ---- Cylindrical::orthoTest: worst=0.000286699

# %% [markdown]
# A list of times for all coefficient sets...

# %%
times = coefs.Times()

# %%
# Slice through the disk midplane
rmin  = -0.04
rmax  = 0.04
pmin  = [ rmin, rmin, 0]
pmax  = [ rmax, rmax, 0]
grid  = [   40,    40,  0]

fields = pyEXP.field.FieldGenerator(times, pmin, pmax, grid)

surfaces = fields.slices(basis, coefs)

# %% [markdown]
# The following routine rounds a value up in leading signficant figure (or down if the value is negative).  Just a
# useful utility for setting contour levels on _nice_ numbers.

# %%
import math

def getLim(x):
    """ Get the one signifcant figure upper/lower limit """
    om = 10.0**np.floor(np.log10(np.abs(x)))
    if x < 0.0:
        return (np.floor(x/om)*om, om)
    else:
        return (np.ceil(x/om)*om, om)

# %%
densmin =  1.0e30
densmax = -1.0e30

for v in surfaces:
    for k in surfaces[v]: 
        if k=='dens':
            densmin = min(densmin, np.min(surfaces[v]['dens']))
            densmax = max(densmax, np.max(surfaces[v]['dens']))

print('Density range', densmin, densmax)
# Out:
# Density range -10739.426 98264.81

# %% [markdown]
# ## Render the disk plane density slice
#
# This next cell will write images to disk for making a movie.  It will take a few minutes to complete.

# %%
from matplotlib import cm, ticker

# Get the evaluation grid
dr = (rmax-rmin)/(40-1)
rr = np.arange(rmin, rmax+0.1*dr, dr)
xv, yv = np.meshgrid(rr, rr)
cnt = 0

# Round to one sig figfor v in surfaces:
dmax, ommax = getLim(math.log10(densmax))

# Make levels
levs = 10.0**np.arange(dmax-4, dmax+0.01, 0.25)

for v in times:
    mat = surfaces[v]['dens']
    mat[mat<levs[0]] = levs[0]
    cc = plt.contourf(xv, yv, mat.transpose(), levels=levs, locator=ticker.LogLocator())
    plt.colorbar(cc)
    plt.title('Time={:4.3f}'.format(v))
    plt.savefig('disk_{:04d}.png'.format(cnt))
    plt.close()
    cnt += 1

# %% [markdown]
# #### Make a movie from the rendered frames
#
# This requires `ffmpeg` to be installed.  It *is* installed in the Docker image...

# %%
os.system('ffmpeg -y -i \'disk_%04d.png\' disk_{0}.mp4'.format('run0'))
# Out:
# ffmpeg version 6.1.1-3ubuntu5 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 13 (Ubuntu 13.2.0-23ubuntu3)
#   configuration: --prefix=/usr --extra-version=3ubuntu5 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --disable-omx --enable-gnutls --enable-libaom --enable-libass --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libglslang --enable-libgme --enable-libgsm --enable-libharfbuzz --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-openal --enable-opencl --enable-opengl --disable-sndio --enable-libvpl --disable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-ladspa --enable-libbluray --enable-libjack --enable-libpulse --enable-librabbitmq --enable-librist --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libx264 --enable-libzmq --enable-libzvbi --enable-lv2 --enable-sdl2 --enable-libplacebo --enable-librav1e --enable-pocketsphinx --enable-librsvg --enable-libjxl --enable-shared
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, image2, from 'disk_%04d.png':
#   Duration: 00:00:40.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc, gbr/unknown/unknown), 640x480 [SAR 3937:3937 DAR 4:3], 25 fps, 25 tbr, 25 tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x566756400000] using SAR=1/1
# [libx264 @ 0x566756400000] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x566756400000] profile High 4:4:4 Predictive, level 3.0, 4:4:4, 8-bit
# [libx264 @ 0x566756400000] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=4 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'disk_run0.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv444p(tv, progressive), 640x480 [SAR 1:1 DAR 4:3], q=2-31, 25 fps, 12800 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x566756095c80] video:1109kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.134442%
# frame= 1001 fps=220 q=-1.0 Lsize=    1122kB time=00:00:39.92 bitrate= 230.3kbits/s speed=8.79x
# [libx264 @ 0x566756400000] frame I:5     Avg QP:19.26  size: 10844
# [libx264 @ 0x566756400000] frame P:252   Avg QP:21.40  size:  1783
# [libx264 @ 0x566756400000] frame B:744   Avg QP:25.55  size:   849
# [libx264 @ 0x566756400000] consecutive B-frames:  0.9%  0.0%  0.0% 99.1%
# [libx264 @ 0x566756400000] mb I  I16..4: 15.6% 56.0% 28.3%
# [libx264 @ 0x566756400000] mb P  I16..4:  1.7%  5.5%  1.0%  P16..4: 18.2%  8.7%  2.3%  0.0%  0.0%    skip:62.7%
# [libx264 @ 0x566756400000] mb B  I16..4:  0.2%  0.8%  0.1%  B16..8: 25.1%  3.6%  0.3%  direct: 0.2%  skip:69.6%  L0:48.2% L1:50.7% BI: 1.1%
# [libx264 @ 0x566756400000] 8x8 transform intra:67.0% inter:88.5%
# [libx264 @ 0x566756400000] coded y,u,v intra: 11.7% 5.4% 8.9% inter: 1.4% 0.5% 1.0%
# [libx264 @ 0x566756400000] i16 v,h,dc,p: 42% 39% 18%  2%
# [libx264 @ 0x566756400000] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 10% 54%  3%  5%  4%  4%  2%  2%
# [libx264 @ 0x566756400000] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 21% 24%  4%  6%  5%  5%  3%  1%
# [libx264 @ 0x566756400000] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x566756400000] ref P L0: 61.1%  2.5% 20.3% 16.1%
# [libx264 @ 0x566756400000] ref B L0: 84.1% 12.8%  3.1%
# [libx264 @ 0x566756400000] ref B L1: 93.0%  7.0%
# [libx264 @ 0x566756400000] kb/s:226.85
# 0

# %% [markdown]
# #### Play the movie

# %%
from IPython.display import Video
Video('disk_{}.mp4'.format('run0'), embed=True, width=800)
# Out:
# <video controls  width="800" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ### A few comments
#
# This simulation was restricted low harmonic and radial orders for speed and owing to the small particle number.  Feel free to regenerate
# the initial conditions with larger particle numbers and increase the number of basis function expansion terms to experiment with this.
# It is best although not strictly necessary to match the maximum order chosen in the initial condition generation to the orders in
# the `config.yml` file used to configure the simulation.
#
# You may have noticed from the coefficient plot and the movie that the dipole component is prominent: the disk is affected by the dipole of the halo.  It is interesting to rerun the halo without the odd-order l harmonics.

# %% [markdown]
# ### A 3d rendering for fun
#
# Make the volume slices for the disk component

# %%
import k3d
from k3d import matplotlib_color_maps

# Slice through the cube perpendicular to the z axis
rmin  = -0.04
rmax  = 0.04
hmin  = -0.005
hmax  =  0.005
pmin  = [ rmin, rmin, hmin]
pmax  = [ rmax, rmax, hmax]
grid  = [   40,   40,   40]

# Only render the final time
fields = pyEXP.field.FieldGenerator(times[-1:], pmin, pmax, grid)

volumes = fields.volumes(basis, coefs)

# %% [markdown]
# Take the log of the density field and find some good contour levels

# %%
# levels for rendering 
dmax, ommax = getLim(math.log10(densmax))
llevs = np.arange(dmax-2, dmax+0.01, 0.5)
levs = 10.0**llevs
print("Level surfaces:", levs, llevs)

v = volumes[times[-1]]['dens']
v[v<levs[0]] = 0.5*levs[0]
v = np.log10(v)
# Out:
# Level surfaces: [  1000.           3162.27766017  10000.          31622.77660168
#  100000.        ] [3.  3.5 4.  4.5 5. ]

# %% [markdown]
# Finally, make the 3d rendering using `k3d`

# %%
plot = k3d.plot(axes=['z', 'y', 'x'])
color_map = k3d.basic_color_maps.Jet

minlev = dmax-2.0
maxlev = dmax

for lev in llevs:
    plot += k3d.marching_cubes(v, level=lev, attribute=[lev], color_map=color_map, color_range=[minlev, maxlev],
                            opacity=0.25,
                            xmin=hmin, xmax=hmax,
                            ymin=rmin, ymax=rmax,
                            zmin=rmin, zmax=rmax,
                            compression_level=9,
                            flat_shading=False)
plot.display()
plot.camera = [0.01, 0.01, 0.01, 0.0, 0.0, 0.0, 1, 0, 0]
# Out:
# Output()

# %% [markdown]
# ### Visualizing the halo wake
#
# We can repeat the same rendering for the halo to see the wake induced by the bar!
#
# First, we need to create the halo basis and read the halo coefficients.

# %%
halo_config = yaml.dump(yaml_db['Components'][0]['force'])
halo_basis = pyEXP.basis.Basis.factory(halo_config)
halo_coefs = pyEXP.coefs.Coefs.factory(outdir + '/outcoef.dark halo.' + runtag)
# Out:
# ---- SLGridSph::ReadH5Cache: successfully read basis cache <sphereSL.cache.test>
# ---- Spherical::orthoTest: worst=0.0375521

# %%
coef_data = halo_coefs.getAllCoefs()

# Let's zero all of the odd order data
for k in range(coef_data.shape[0]):
    l, m = pyEXP.basis.SphericalSL.invI(k)
    if l%2!=0 or m%2!=0: coef_data[k,:,:] *= 0.0

# Reset the coefficient data
for i in range(coef_data.shape[2]):
    halo_coefs.setMatrix(times[i], coef_data[:,:,i])

# %% [markdown]
# Now, we can render the volume resconstruction for a cube around the disk with same extent as the disk rendering.

# %%
rmin  = -0.04
rmax  =  0.04
pmin  = [ rmin, rmin, rmin]
pmax  = [ rmax, rmax, rmax]
grid  = [   40,   40,   40]

# Only render the final time
halo_fields = pyEXP.field.FieldGenerator(times[-1:], pmin, pmax, grid)

halo_volumes = halo_fields.volumes(halo_basis, halo_coefs)

# %% [markdown]
# To emphasize the wake, we'll render the non-spherical components only

# %%
# Get the non-axisymmetric density

v = halo_volumes[times[-1]]['dens m>0']

# Get the field range to set the contour surfacers
dmin = np.min(v)
dmax = np.max(v)

print('Density range', dmin, dmax)

# Contour surface levels for rendering 
drange = (dmax - dmin)/6
levs = np.arange(dmin, dmax+0.01*drange, drange)

# Report it out
print("Level surfaces:", levs)

# Tell k3d to render the scene
plot2 = k3d.plot(axes=['z', 'y', 'x'])
color_map = k3d.basic_color_maps.Jet

for lev in levs:
    plot2 += k3d.marching_cubes(v, level=lev, attribute=[lev], color_map=color_map, color_range=[levs[0], levs[-1]],
                            opacity=0.25,
                            xmin=rmin, xmax=rmax,
                            ymin=rmin, ymax=rmax,
                            zmin=rmin, zmax=rmax,
                            compression_level=9,
                            flat_shading=False)
plot2.display()
plot2.camera = [0.01, 0.01, 0.01, 0.0, 0.0, 0.0, 1, 0, 0]
# Out:
# Density range -576.38727 803.6581
# Level surfaces: [-576.38726807 -346.37969971 -116.37213135  113.63543701  343.64300537
#   573.65057373  803.65814209]
# Output()

# %% [markdown]
# ## Visualizing the disk velocity fields
#
# First, get the YAML config and construct the velocity basis:

# %%
vel_config = yaml_db['Output'][6]
vel_config['id'] = 'velocity'
# remove unwanted keys
if 'nint' in vel_config['parameters'].keys(): del vel_config['parameters']['nint']
if 'name' in vel_config['parameters'].keys(): del vel_config['parameters']['name']
print(yaml.dump(vel_config))
# Out:
# id: velocity
# parameters:
#   ascl: 0.01
#   delta: 0.0002
#   dof: 2
#   lmax: 4
#   model: expon
#   nmax: 12
#   rmapping: 0.01
#   rmax: 0.1
#   rmin: 0.0001

# %%
# Make the velocity basis
vel_basis  = pyEXP.basis.Basis.factory(yaml.dump(vel_config))
# Out:
# FieldBasis::orthoTest: worst=4.07282e-15

# %% [markdown]
# Next, read the coefficients:

# %%
# read in the coefficients
vcoeffile = outdir + '/velcoef.star disk.' + runtag
vcoefs0 = pyEXP.coefs.Coefs.factory(vcoeffile, 1)
vcoefs  = vcoefs0.deepcopy()

# %% [markdown]
# This code block zeros out all but even nonaxisymmetric coefficients.  You can change this to whatever suits your need...

# %%
# Restrict to even harmonics
for T in vcoefs.Times():
    db = vcoefs(T)
    newdata = np.zeros(db.shape, dtype=db.dtype)
    for m in range(db.shape[1]):
        if m>0 and m%2==0: newdata[:,m,:] += db[:,m,:]
    vcoefs.setMatrix(T, newdata)

# %% [markdown]
# Tell the `FieldGenerator` to render surfaces for all fields.

# %%
times = vcoefs.Times()
rmax  = 0.03
ngrd  = 100
pmin  = [ -rmax, -rmax, 0.0]
pmax  = [  rmax,  rmax, 0.0]
grid  = [  ngrd,  ngrd,   0]

fields = pyEXP.field.FieldGenerator(times, pmin, pmax, grid)

print('Created fields instance')

# Get surfaces for the restricted and full coefficient sets
vsurfaces  = fields.slices(vel_basis, vcoefs )
vsurfaces0 = fields.slices(vel_basis, vcoefs0)
# Out:
# Created fields instance

# %% [markdown]
# Make a `meshgrid` for plotting.

# %% [markdown]
# # Get the shape from the surface maps
# keys = list(vsurfaces.keys())
# nx = vsurfaces[keys[0]]['density'].shape[0]
# ny = vsurfaces[keys[0]]['density'].shape[1]
#
# # Make the mesh for pyplot
# x = np.linspace(-rmax, rmax, nx)
# y = np.linspace(-rmax, rmax, ny)
# xv, yv = np.meshgrid(x, y)
#
# # Set the font size to something we can see!
# plt.rcParams.update({'font.size': 14})

# %% [markdown]
# Finally, plot some surfaces.  Here, we show density, radial and vertical velocity fields.

# %%
key1 = 'v_R'
key2 = 'v_z'

# You can decrease the stride to get more frames...
for tim in vcoefs.Times()[::100]:
    # Create the subplot geometry
    fig, ax = plt.subplots(1, 3, sharex='all', sharey='all', figsize=(14,4))
    for v in ax: 
        v.set_aspect('auto')
        v.set_box_aspect(1)

    # Get the data matrices
    mat1 = vsurfaces[tim][key1]/vsurfaces0[tim]['density']
    mat2 = vsurfaces[tim][key2]/vsurfaces0[tim]['density']

    # Pick some levels for contouring
    v1 = np.linspace(-0.2, 0.2, 10, endpoint=True)
    v2 = np.linspace(-0.1, 0.1, 10, endpoint=True)

    # Make the middle/center field for key1
    cont1 = ax[1].contour(xv, yv, mat1.transpose(), levels=v1, colors='k')
    cont2 = ax[1].contourf(xv, yv, mat1.transpose(), levels=v1)
    plt.colorbar(cont2, ax=ax[1], shrink=0.3)
    ax[1].set_xlabel('x')
    ax[1].set_ylabel('y')
    ax[1].set_title('${}$'.format(key1))

    # Make the right-hand field for key2
    cont3 = ax[2].contour(xv, yv, mat2.transpose(), levels=v2, colors='k')
    cont4 = ax[2].contourf(xv, yv, mat2.transpose(), levels=v2)
    plt.colorbar(cont4, ax=ax[2], shrink=0.3)
    ax[2].set_xlabel('x')
    ax[2].set_ylabel('y')
    ax[2].set_title('${}$'.format(key2))

    # Make the left-hand field (density)
    mat3 = vsurfaces0[tim]['density']
    cont5 = ax[0].contour(xv, yv, mat2.transpose(), colors='k')
    cont6 = ax[0].contourf(xv, yv, mat2.transpose())
    plt.colorbar(cont6, ax=ax[0], shrink=0.3)
    ax[0].set_title(r'T={:4.3f}  $\Sigma(x, y)$'.format(tim))
    plt.show()

# %% [markdown]
# ***
#
# ## Where do you want to go next?
#
# - [Return to Table of Contents](../README.ipynb)
# - [Back to previous notebook](../Orbits/orbits%20with%20a%20custom%20force.ipynb)
# - [Go to next notebook](cube%20run.ipynb)
